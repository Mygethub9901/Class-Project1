# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Library

# %%
df=pd.read_csv(r'C:\Users\Ankita\Desktop\adver.csv')

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# Loading the data

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %% [markdown]
# Drop Unnamed: 0 because it is not much important

# %%
df.shape
# Out:
# (200, 4)

# %% [markdown]
# IN ABOVE DATASET 200 ROWS AND 4 COLUMNS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# Describe dataset Information

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# There was no missing values present in dataset

# %%
df.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %% [markdown]
# Describe dataset columns

# %%
df.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# Describe dataset columns type

# %%
df['sales'].unique()
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. ,  5.6,
#        15.5, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,  9.5, 12.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 14.9, 23.2, 14.8,
#        11.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1, 24.2,
#        15.7, 14. , 13.4, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 12.3, 13.6, 21.7, 15.2, 16. , 16.7, 11.2,  7.3, 19.4,
#        22.2, 11.5, 16.9, 11.7, 17.2, 19.2, 19.8, 21.8, 14.1, 12.6, 12.2,
#         9.4,  6.6,  7. , 11.6, 19.7, 24.7,  1.6, 12.7,  5.7, 19.6, 10.8,
#        20.8, 10.9, 20.1, 10.3, 16.1, 15.6,  3.2, 15.3, 14.4, 13.3,  8. ,
#         8.4, 14.5,  7.6, 27. , 26.2, 17.6, 17.3,  6.7,  9.9,  5.9, 25.5])

# %% [markdown]
# Describe target columns unique values

# %%
df.loc[df['sales']==" "]
# Out:
# Empty DataFrame
# Columns: [TV, radio, newspaper, sales]
# Index: []

# %% [markdown]
# There was no blank space present in target columns

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Describe dataset

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# Heatmap shows the relation of all independent columns

# %%
df["sales"].value_counts()
# Out:
# 9.7     5
# 12.9    4
# 11.7    4
# 15.9    4
# 25.4    3
#        ..
# 15.7    1
# 14.2    1
# 11.2    1
# 19.4    1
# 18.5    1
# Name: sales, Length: 121, dtype: int64

# %% [markdown]
# Describe target column values

# %%
df.hist( bins = 10, figsize = (10,10))
plt.show()

# %% [markdown]
# Describe dataset using hist

# %%
sns.pairplot(df, size=2.5)
plt.show()

# %% [markdown]
# describe dataset using pairplot

# %% [markdown]
# Checking Distribution

# %%
sns.distplot(df["TV"])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df["radio"])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(df["newspaper"])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# Here all column are not normally distributed

# %% [markdown]
# Checking Outliers:

# %%
sns.boxplot(df["TV"])
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.boxplot(df["radio"])
# Out:
# <AxesSubplot:xlabel='radio'>

# %%
sns.boxplot(df["newspaper"])
# Out:
# <AxesSubplot:xlabel='newspaper'>

# %% [markdown]
# Here only newspaper column outlier present

# %% [markdown]
# Bi varient analysis:

# %%
sns.pairplot(df, x_vars=['newspaper', 'radio','TV',], y_vars='sales', height=4, aspect=1, kind='scatter')
plt.show()

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs radio')
sns.scatterplot(df["TV"],df["radio"],alpha=0.5,c=(0,0,0),edgecolors='r')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Comparsion between two columns

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs radio')
#sns.scatterplot(df["TV"],df["radio"],alpha=0.5,c=(0,0,0),edgecolors='r')
sns.scatterplot(df["TV"],df["radio"],hue=df["sales"])
plt.show()

# %% [markdown]
# Comparsion between two columns

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs newspaper')
sns.scatterplot(df["TV"],df["newspaper"],alpha=0.5,c=(0,0,0),edgecolors='r')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Comparsion between two columns using target variable

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs newspaper')
#sns.scatterplot(df["TV"],df["radio"],alpha=0.5,c=(0,0,0),edgecolors='r')
sns.scatterplot(df["TV"],df["newspaper"],hue=df["sales"])
plt.show()

# %% [markdown]
# Comparsion between two columns using target variable

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs radio vs newspaper')
sns.scatterplot(df["TV"],df["radio"],df["newspaper"],alpha=0.5,c=(0,0,0),edgecolors='r')
plt.show()

# %% [markdown]
# Comparsion between three columns

# %%
plt.figure(figsize=[10,6])
plt.title('TV vs radio vs newspaper')
#sns.scatterplot(df["TV"],df["radio"],alpha=0.5,c=(0,0,0),edgecolors='r')
sns.scatterplot(df["TV"],df["radio"],df["newspaper"],hue=df["sales"])
plt.show()

# %% [markdown]
# Comparsion between three columns using target variable

# %% [markdown]
# Multi Varient Analysis:

# %%
sns.pairplot(df, hue='sales')

# %% [markdown]
# Check correlation:

# %%
cor=df.corr()

# %%
cor
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking correlation of all the independent column with target column

# %%
plt.figure(figsize=(15,10))
df.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# correlation with different way

# %%
df.shape
# Out:
# (200, 4)

# %% [markdown]
# Use zscore method for data loss:

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (198, 4)

# %%
df.shape
# Out:
# (200, 4)

# %%
(1/200)
# Out:
# 0.005

# %%
Data_loss=((200-199)/200)*100

# %%
Data_loss
# Out:
# 0.5

# %% [markdown]
# Use IQR method for data loss

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df_new=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df_new.shape
# Out:
# (198, 4)

# %%
Data_loss=((200-199)/200)*100

# %%
Data_loss
# Out:
# 0.5

# %% [markdown]
# Checking skewness:

# %%
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df)
df=pd.DataFrame(dfpt,columns=df.columns)

# %% [markdown]
# Use power transform to remove skewness

# %%
df.skew()
# Out:
# TV          -0.315199
# radio       -0.242968
# newspaper   -0.077942
# sales       -0.007841
# dtype: float64

# %% [markdown]
# After removing skewness

# %%
x=df.drop("sales",axis=1)
y=df["sales"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Loading libraryies

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %% [markdown]
# Use different models to select best accracy score and select best model.

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.938754991556691

# %% [markdown]
# LinearRegression is use to check accuracy score

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Imort library

# %%
parameters={'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.9372079786020395

# %% [markdown]
# Check cross validation score

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9010741029142786

# %% [markdown]
# for lasso and ridge it is very important to find bet alpha value so use hyper parameter tunning on it

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
ri=Ridge()
clf=GridSearchCV(ri,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %%
ri=Ridge(alpha=1)
ri.fit(x_train,y_train)
ri.score(x_train,y_train)
pred_ri=ri.predict(x_test)
rii=r2_score(y_test,pred_ri)
rii
# Out:
# 0.938385942259346

# %% [markdown]
# for lasso and ridge it is very important to find bet alpha value so use hyper parameter tunning on it

# %%
cv_score=cross_val_score(ri,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9006919138862605

# %% [markdown]
# Check cross validation score

# %%
KNN = KNeighborsRegressor()
KNN.fit(x_train, y_train)
KNN.score(x_train,y_train)
pred_KNN= KNN.predict(x_test)
KNN=r2_score(y_test, pred_KNN)
KNN
# Out:
# 0.95790013004901

# %% [markdown]
# Here use KNeighborsRegressor model

# %%
KNN_score=cross_val_score(KNN,x,y,cv=5)
KNN_mean=KNN_score.mean()
KNN_mean
# Out:
# 0.9006919138862605

# %% [markdown]
# Check cross validation score

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 98.40053406898286

# %% [markdown]
# Here use RandomForestRegressor model

# %%
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross cal score:',rfs*100)
# Out:
# cross cal score: 98.40053406898286

# %% [markdown]
# Check cross validation score

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred_sv=sv.predict(x_test)
svv=r2_score(y_test,pred_sv)
svv
# Out:
# 0.9637342997233481

# %% [markdown]
# Here use SVR

# %%
svscore=cross_val_score(rf,x,y,cv=5)
sv=svscore.mean()
print('cross cal score:',sv*100)
# Out:
# cross cal score: 96.80493822317965

# %% [markdown]
# Check cross validation score

# %% [markdown]
# Here our RandomForestRegressor is the best model so apply hyperparameter tunning on it

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Import GridSearchCV library

# %%
import numpy as np

# %%
from sklearn.ensemble import RandomForestRegressor
parameters = {'n_estimators': [200,700],
                'max_features': ['auto','sqrt','log2'],
                 'max_depth': [4,5,6,7,8],
              'criterion' : ['mse','mae']}

# %% [markdown]
# Use  RandomForestRegressor parameter list for select best parameter.

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %% [markdown]
# Import GridSearchCV library

# %% [markdown]
# Intialize

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %% [markdown]
# Best parameter list of RandomForestRegressor

# %%
GCV.best_params_
# Out:
# {'criterion': 'mae',
#  'max_depth': 7,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
Final_mod2 = RandomForestRegressor(criterion= 'mae',max_depth=7,max_features='auto',n_estimators=700)
Final_mod2.fit(x_train,y_train)
pred = Final_mod2.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print(rfs*100)
# Out:
# 98.40053406898286

# %% [markdown]
# Finally print best score

# %% [markdown]
# Saving the model

# %%
import joblib
joblib.dump(rfs,"Advertising.pkl")
# Out:
# ['Advertising.pkl']

# %% [markdown]
# Loading the model

# %%
mod=joblib.load("Advertising.pkl")

# %%
print(Final_mod2.predict(x_test))
# Out:
# [ 0.29398816 -0.99746086 -1.44358611 -0.2706346  -0.18312589  0.59630111
#   1.85946465 -0.79640654 -0.22849187 -0.08863585  0.74075434 -0.32905833
#  -2.03599116  0.33155607  1.88322583 -0.7053265  -0.18541048 -0.15449649
#  -0.33767399  0.21676029  1.37175026 -1.28893836  1.45577572 -0.76554768
#   0.43212426 -0.73197577 -0.35884092 -0.27808947 -1.73256431 -1.24449238
#  -0.47477836  1.90530338  0.51661671  1.35794898 -1.51861648  1.26127936
#  -0.03654588  1.52793018 -0.46458248 -1.37215355]

# %% [markdown]
# Finally creating best model
