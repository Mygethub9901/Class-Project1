# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Library

# %%
df=pd.read_csv(r'C:\Users\Ankita\Desktop\avocado.csv')

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %% [markdown]
# Loading the data First 5 rows

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %% [markdown]
# Loading the data Last 5 rows

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %% [markdown]
# Drop the Unnamed column because it is not more important

# %%
df.shape
# Out:
# (18249, 13)

# %% [markdown]
# In above dataset 18249 rows and 13 columns

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# Describe dataset columns type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Describe dataset information

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# There was no missing values in this dataset

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# Describe Dataset

# %%
df['AveragePrice'].unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %% [markdown]
# Describe Target column Unique values

# %%
df.loc[df['AveragePrice']==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %% [markdown]
# There was no blank space present in target columns

# %%
df = df.rename(columns = { '4046' : 'PLU4046', '4225' : 'PLU4225', '4770' : 'PLU4770'})

# %% [markdown]
# Rename some columns in dataset

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume  PLU4046    PLU4225  PLU4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85    48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81    58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67   130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41    72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39    75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# Describe dataset after Rename some column in Dataset

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# Heatmap shows the relation of all independent columns

# %%
df.AveragePrice.describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %% [markdown]
# Describe Target column

# %% [markdown]
# Univarient Analysis:

# %%
sns.countplot(df['AveragePrice']);

# %% [markdown]
# Distribution of target variable

# %%
sns.countplot(df['type']);

# %% [markdown]
# Distribution of type column

# %%
sns.countplot(df['region']);

# %% [markdown]
# Distribution of region column

# %%
sns.countplot(df['year']);

# %% [markdown]
# Distribution of year column

# %% [markdown]
# Checking Distribution

# %%
sns.distplot(df["AveragePrice"])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df["Total Volume"])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df["PLU4046"])
# Out:
# <AxesSubplot:xlabel='PLU4046', ylabel='Density'>

# %%
sns.distplot(df["PLU4225"])
# Out:
# <AxesSubplot:xlabel='PLU4225', ylabel='Density'>

# %%
sns.distplot(df["PLU4770"])
# Out:
# <AxesSubplot:xlabel='PLU4770', ylabel='Density'>

# %%
sns.distplot(df["Total Bags"])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df["Small Bags"])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df["Large Bags"])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df["XLarge Bags"])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(df["year"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
df['type'] = label.fit_transform(df['type'])
df['region'] = label.fit_transform(df['region'])

# %%
sns.distplot(df["type"])
# Out:
# <AxesSubplot:xlabel='type', ylabel='Density'>

# %%
sns.distplot(df["region"])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %% [markdown]
# Here data is not normally distributed

# %% [markdown]
# Checking Outliers:

# %%
sns.boxplot(df["AveragePrice"])
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %%
sns.boxplot(df["Total Volume"])
# Out:
# <AxesSubplot:xlabel='Total Volume'>

# %%
sns.boxplot(df["PLU4046"])
# Out:
# <AxesSubplot:xlabel='PLU4046'>

# %%
sns.boxplot(df["PLU4225"])
# Out:
# <AxesSubplot:xlabel='PLU4225'>

# %%
sns.boxplot(df["PLU4770"])
# Out:
# <AxesSubplot:xlabel='PLU4770'>

# %%
sns.boxplot(df["Total Bags"])
# Out:
# <AxesSubplot:xlabel='Total Bags'>

# %%
sns.boxplot(df["Small Bags"])
# Out:
# <AxesSubplot:xlabel='Small Bags'>

# %%
sns.boxplot(df["Large Bags"])
# Out:
# <AxesSubplot:xlabel='Large Bags'>

# %%
sns.boxplot(df["XLarge Bags"])
# Out:
# <AxesSubplot:xlabel='XLarge Bags'>

# %%
sns.boxplot(df["type"])
# Out:
# <AxesSubplot:xlabel='type'>

# %%
sns.boxplot(df["year"])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.boxplot(df["region"])
# Out:
# <AxesSubplot:xlabel='region'>

# %% [markdown]
# Here only type,region,year column outlier are not present and remaning columns are outlier present

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month
df.drop('Date', axis=1, inplace=True)

# %% [markdown]
# Here create month column from date column and drop date column

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# PLU4046         float64
# PLU4225         float64
# PLU4770         float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Month             int64
# dtype: object

# %% [markdown]
# Describe datatype of all column in dataset

# %%
df.head()
# Out:
#    AveragePrice  Total Volume  PLU4046    PLU4225  PLU4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85    48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81    58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67   130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41    72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39    75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# 0     8603.62       93.25          0.0     0  2015       0     12
# 1     9408.07       97.49          0.0     0  2015       0     12
# 2     8042.21      103.14          0.0     0  2015       0     12
# 3     5677.40      133.76          0.0     0  2015       0     12
# 4     5986.26      197.69          0.0     0  2015       0     11

# %% [markdown]
# Describe first 5 rows in dataset

# %% [markdown]
# Bi-Varient Analysis:

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="year",y="Month",hue=df["AveragePrice"],data=df);

# %% [markdown]
# Comparision between year and month column hue to Target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="type",y="region",hue=df["AveragePrice"],data=df);

# %% [markdown]
# Comparision between type and region column hue to Target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="PLU4046",y="PLU4225",hue=df["AveragePrice"],data=df);

# %% [markdown]
# Comparision between PLU4046 and PLU4225 column hue to Target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="PLU4225",y="PLU4770",hue=df["AveragePrice"],data=df);

# %% [markdown]
# Comparision between PLU4225 and PLU4770 column hue to Target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="Small Bags",y="Large Bags",hue=df["Total Bags"],data=df);

# %% [markdown]
# Comparision between Small Bags and Large Bags column hue to Total Bags column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(x="Small Bags",y="XLarge Bags",hue=df["Total Bags"],data=df)
# Out:
# <AxesSubplot:title={'center':'comparision'}, xlabel='Small Bags', ylabel='XLarge Bags'>

# %% [markdown]
# Comparision between Small Bags and XLarge Bags column hue to Total Bags column

# %% [markdown]
# Multi Varient Analysis:

# %%
df.hist( bins = 10, figsize = (10,10))
plt.show()

# %% [markdown]
# Describe dataset using HistPlot

# %%
sns.pairplot(df, hue='AveragePrice')

# %% [markdown]
# Describe dataset using PairPlot

# %%
cor=df.corr()

# %%
cor
# Out:
#               AveragePrice  Total Volume   PLU4046   PLU4225   PLU4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# PLU4046          -0.208317      0.977863  1.000000  0.926110  0.833389
# PLU4225          -0.172928      0.974181  0.926110  1.000000  0.887855
# PLU4770          -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking correlation of all the independent column with target column

# %%
plt.figure(figsize=(15,10))
df.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# correlation with different way

# %% [markdown]
# Checking skewness:

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# PLU4046          8.648220
# PLU4225          8.942466
# PLU4770         10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df)
df=pd.DataFrame(dfpt,columns=df.columns)

# %% [markdown]
# Use power transform to remove skewness

# %%
df.skew()
# Out:
# AveragePrice    0.005596
# Total Volume    0.011171
# PLU4046        -0.022679
# PLU4225        -0.017740
# PLU4770         0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.213156
# region         -0.261443
# Month          -0.146584
# dtype: float64

# %% [markdown]
# After removing skewness

# %% [markdown]
# Use zscore method for data loss:

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (18141, 13)

# %%
df.shape
# Out:
# (18249, 13)

# %%
(108/18141)
# Out:
# 0.0059533653051099715

# %% [markdown]
# Use IQR method for data loss

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
new_df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
new_df.shape
# Out:
# (17878, 13)

# %%
x = df.drop('AveragePrice', axis=1)
y = df['AveragePrice']

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing Libraryies

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %% [markdown]
# Use different models to select best accracy score and select best model.

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.5696937647254985

# %% [markdown]
# LinearRegression is use to check accuracy score

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Inporting Libraryies

# %%
parameters={'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.569722483993431

# %% [markdown]
# Use Lasso model r2 Score

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.25565931147862947

# %% [markdown]
# Lasso model Cross validation Score

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
ri=Ridge()
clf=GridSearchCV(ri,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %% [markdown]
# Use model Ridge Score

# %%
ri=Ridge(alpha=1)
ri.fit(x_train,y_train)
ri.score(x_train,y_train)
pred_ri=ri.predict(x_test)
rii=r2_score(y_test,pred_ri)
rii
# Out:
# 0.5697050190622901

# %%
cv_score=cross_val_score(ri,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.255593259229447

# %% [markdown]
# Ridge model Cross validation Score

# %%
KNN = KNeighborsRegressor()
KNN.fit(x_train, y_train)
KNN.score(x_train,y_train)
pred_decision= KNN.predict(x_test)
KNNS=r2_score(y_test, pred_decision)
print('R2 Score:',KNNS*100)
# Out:
# R2 Score: 88.31047704444885

# %% [markdown]
# Use model KNN r2 Score

# %%
cv_score=cross_val_score(KNN,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.255593259229447

# %% [markdown]
# KNN model Cross validation Score

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 90.19393754735032

# %% [markdown]
# Use model RandomForestRegressor r2 Score

# %%
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross cal score:',rfc*100)
# Out:
# cross cal score: 90.19393754735032

# %% [markdown]
# RandomForestRegressor model Cross validation Score

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred_sv=sv.predict(x_test)
svv=r2_score(y_test,pred_sv)
svv
# Out:
# 0.7855708770047334

# %% [markdown]
# Use model SVV r2 Score

# %%
svscore=cross_val_score(sv,x,y,cv=5)
svc=svscore.mean()
print('cross cal score:',svc*100)
# Out:
# cross cal score: 78.55708770047333

# %% [markdown]
# SVV model Cross validation Score

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# Importing Library

# %%
Ad = AdaBoostRegressor()
Ad.fit(x_train, y_train)
Ad.score(x_train, y_train)
pred_decision=Ad.predict(x_test)
Add=r2_score(y_test,pred_decision)
print('R2 Score:',Add*100)
# Out:
# R2 Score: 62.53483216816994

# %% [markdown]
# Use model AdaBoostRegressor r2 Score

# %%
Adscore=cross_val_score(Ad,x,y,cv=5)
Adx=Adscore.mean()
print('cross cal score:',Adx*100)
# Out:
# cross cal score: 62.53483216816994

# %% [markdown]
# AdaBoostRegressor model Cross validation Score

# %%
GB = GradientBoostingRegressor()
GB.fit(x_train, y_train)
GB.score(x_train, y_train)
pred = GB.predict(x_test)
GBB=r2_score(y_test, pred)
print('R2 score',GBB*100)
# Out:
# R2 score 76.39320487930654

# %% [markdown]
# Use model GradientBoostingRegressor r2 Score

# %%
GBscore=cross_val_score(GB,x,y,cv=5)
GBC=GBscore.mean()
print('cross cal score:',GBC*100)
# Out:
# cross cal score: 76.39320487930654

# %% [markdown]
# model Cross validation Score

# %%
from sklearn.tree import DecisionTreeRegressor

DTC = DecisionTreeRegressor()
DTC.fit(x_train, y_train)
DTC.score(x_train,y_train)
pred_decision= DTC.predict(x_test)
DTCC=r2_score(y_test,pred_decision)
print('R2 Score:',DTCC*100)
# Out:
# R2 Score: 79.76921566916258

# %% [markdown]
# Use model DTC r2 Score

# %%
DTCscore=cross_val_score(DTC,x,y,cv=5)
DTCS=DTCscore.mean()
print('cross cal score:',DTCS*100)
# Out:
# cross cal score: 79.76921566916258

# %% [markdown]
# model Cross validation Score

# %% [markdown]
# Here RandomForestRegressor  is score is high so it is our best model Apply hyper parameter tunning on it

# %%
from sklearn.model_selection import GridSearchCV

# %%
import numpy as np

# %% [markdown]
# Import GridsearchCV

# %%
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion' : ['mse','mae'],
              'max_features': ["auto","log2"],
              'max_depth' : [4,5]}

# %% [markdown]
# Import parameters

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5,n_jobs=-1)

# %% [markdown]
# Import GridSearchCV library

# %% [markdown]
# Intialize

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse', 'max_depth': 5, 'max_features': 'auto'}

# %% [markdown]
# Best parameter list of RandomForestRegressor

# %%
rf = RandomForestRegressor(criterion= 'mse',max_features='auto',max_depth=5)
rf.fit(x_train,y_train)
pred = rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print(rfs*100)
# Out:
# cross cal score: 90.2484903406848

# %% [markdown]
# Finally print best score

# %%
import joblib
joblib.dump(rfs,"Avocado.pkl")
# Out:
# ['Avocado.pkl']

# %% [markdown]
# Loading the model

# %%
mod=joblib.load("Avocado.pkl")

# %%
print(Final_mod2.predict(x_test))
# Out:
# [-0.13909587 -0.88721022  0.51614248 ... -0.55695727  1.04039932
#  -1.0091512 ]

# %% [markdown]
# Finally creating best model
