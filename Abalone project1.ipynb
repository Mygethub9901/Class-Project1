# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Imporing Lybraryies

# %%
df=pd.read_csv(r'C:\Users\Ankita\Desktop\abadone.csv')
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Loading Data
# There is no missing values so no need to use missing value handling

# %%
df['age'] = df.Rings + 1.5

# %%
df.drop('Rings', axis=1, inplace=True)

print("Data loaded Successfully!")
# Out:
# Data loaded Successfully!

# %% [markdown]
# rings column add 1.5 each value and converted into age column and data loaded successfully into the dataset

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %% [markdown]
# Loading Data after inserting age column

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 4172          0.2390        0.2490  12.5
# 4173          0.2145        0.2605  11.5
# 4174          0.2875        0.3080  10.5
# 4175          0.2610        0.2960  11.5
# 4176          0.3765        0.4950  13.5

# %% [markdown]
# loading data last 5 rows into dataset

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# we have 4177 rows and 9 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   age             4177 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# Information all the column into the dataset

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# age               0
# dtype: int64

# %% [markdown]
# There was no missing value in the dataset

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'age'],
#       dtype='object')

# %% [markdown]
# Column information into the dataset

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# age               float64
# dtype: object

# %% [markdown]
# We have all float type of value in all independent variable
# and age is our target varible

# %%
df['age'].unique()
# Out:
# array([16.5,  8.5, 10.5, 11.5,  9.5, 21.5, 17.5, 20.5, 15.5, 12.5, 13.5,
#        19.5, 14.5,  6.5,  5.5,  7.5, 22.5, 18.5, 23.5,  2.5,  4.5, 27.5,
#        24.5, 30.5,  3.5, 28.5, 26.5, 25.5])

# %% [markdown]
# Unique value in age column

# %%
df.loc[df['age']==" "]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, age]
# Index: []

# %% [markdown]
# Check the Blank space in dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# Describe the dataset

# %%
sns.countplot(df['Sex']);
print(df["Sex"].value_counts())
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# Class inbalanced category in this column

# %%
sns.countplot(df['Sex']);

# %% [markdown]
# Class inbalanced category in this column

# %% [markdown]
# Checking Distribution Normalize or Not

# %%
sns.distplot(df["Length"])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df["Height"])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
sns.distplot(df["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(df["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Density'>

# %% [markdown]
# Here only height column is normally distributed

# %% [markdown]
# Check the outlier present in which columns in the dataset

# %%
 sns.boxplot(df["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
sns.boxplot(df["Length"])
# Out:
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(df["Diameter"])
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(df["Height"])
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
 sns.boxplot(df["Whole weight"])
# Out:
# <AxesSubplot:xlabel='Whole weight'>

# %%
 sns.boxplot(df["Shucked weight"])
# Out:
# <AxesSubplot:xlabel='Shucked weight'>

# %%
 sns.boxplot(df["Viscera weight"])
# Out:
# <AxesSubplot:xlabel='Viscera weight'>

# %%
 sns.boxplot(df["Shell weight"])
# Out:
# <AxesSubplot:xlabel='Shell weight'>

# %%
sns.boxplot(df["age"])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.pairplot(df, hue='age')

# %% [markdown]
# Here only whole weight and sex column outlier is present

# %%
x=df.drop('age',axis=1) #Predictors
y=df['age'] #target
x.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0  2.0   0.455     0.365   0.095        0.5140          0.2245
# 1  2.0   0.350     0.265   0.090        0.2255          0.0995
# 2  0.0   0.530     0.420   0.135        0.6770          0.2565
# 3  2.0   0.440     0.365   0.125        0.5160          0.2155
# 4  1.0   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# Encoding:

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %% [markdown]
# Use Ordinal Encoding

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings          age
# count     4177.000000     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684    11.433684
# std          0.221963        0.109614      0.139203     3.224169     3.224169
# ...

# %% [markdown]
# Describe the dataset

# %%
df.corr()
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
# age            -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings  \
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking Correlation with target column:

# %%
plt.figure(figsize=(15,10))
df.corr()['age'].sort_values(ascending=False).drop(['age']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Corerlation in different way

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# age               1.114102
# dtype: float64

# %%
df.dtypes
# Out:
# Sex               float64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# age               float64
# dtype: object

# %% [markdown]
# Checking skewness

# %%
 df.shape
# Out:
# (4177, 10)

# %% [markdown]
# Dataset how many column and rows present

# %% [markdown]
# Z score use to remove outlier

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   6,    6,   72,   72,   81,   83,   83,  129,  163,  164,  165,
#          165,  165,  166,  166,  166,  167,  167,  168,  170,  181,  181,
#          232,  232,  236,  236,  236,  237,  237,  238,  238,  239,  270,
#          270,  275,  275,  277,  278,  278,  294,  294,  310,  310,  313,
#          313,  314,  314,  334,  351,  351,  355,  355,  358,  358,  362,
#          362,  375,  375,  416,  416,  417,  417,  428,  428,  431,  431,
#          433,  433,  469,  469,  478,  478,  480,  480,  501,  501,  526,
#          526,  530,  530,  572,  572,  628,  628,  673,  673,  674,  674,
#          675,  675,  678,  678,  694,  696,  696,  719,  719,  720,  720,
#          744,  744,  754,  754,  756,  756,  811,  811,  891,  891,  891,
#         1048, 1051, 1051, 1052, 1193, 1197, 1199, 1202, 1204, 1206, 1206,
#         1207, 1207, 1207, 1207, 1209, 1209, 1257, 1417, 1417, 1418, 1422,
#         1426, 1427, 1427, 1427, 1428, 1429, 1429, 1528, 1754, 1756, 1757,
# ...

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %%
df_new_z.shape
# Out:
# (4027, 10)

# %%
Data_loss=((4177-4027)/4177)*100

# %%
Data_loss
# Out:
# 3.5910940866650707

# %% [markdown]
# After applying Z score dataloss

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df_new=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df_new.shape
# Out:
# (3781, 10)

# %% [markdown]
# Use IQR remove outlier

# %% [markdown]
# After applying method we have lose data more data persent so i am not removing outlier

# %%
df.skew()
# Out:
# Sex              -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# age               1.114102
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df)
df=pd.DataFrame(dfpt,columns=df.columns)

# %% [markdown]
# Removing Outlier using Power Transformer

# %%
df.skew()
# Out:
# Sex              -0.176442
# Length           -0.066669
# Diameter         -0.065977
# Height           -0.115483
# Whole weight     -0.003980
# Shucked weight    0.027351
# Viscera weight    0.039780
# Shell weight      0.023390
# Rings             0.004429
# age              -0.006715
# dtype: float64

# %%
x=df.drop('age',axis=1) 
y=df['age']

# %% [markdown]
# Scalling the data using MIN-MAX scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Find the best random_state use here

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.9998994826927613

# %% [markdown]
# Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Here no need use hyper parameter tunning all the model but to select best random state we use Gridsearch CV

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.9999008699834001

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9999514997200055

# %%
from sklearn.linear_model import Ridge
parameters={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
ri=Ridge()
clf=GridSearchCV(ri,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1e-15}

# %%
ri=Ridge(alpha=0.0001,random_state=1e-15)
ri.fit(x_train,y_train)
ri.score(x_train,y_train)
pred_ri=ri.predict(x_test)
rii=r2_score(y_test,pred_ri)
rii
# Out:
# 0.9998994828324118

# %%
cv_score=cross_val_score(ri,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9999516737051175

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

parameters =  {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
sv=SVR()
clf=GridSearchCV(sv,parameters) 
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
sv=SVR(C=100,gamma=0.0001,kernel="rbf")
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred_sv=sv.predict(x_test)
svv=r2_score(y_test,pred_sv)
svv
# Out:
# 0.998632204741826

# %% [markdown]
# Ensemble Technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 99.77047738845448

# %%
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
#cv_mean
print('cross cal score:',rfs*100)
# Out:
# cross cal score: 99.77047738845448

# %% [markdown]
# Linear Regressor best model

# %% [markdown]
# Here we already apply GridSearchCv So no need Hyper Parameter tuning

# %%
import joblib
joblib.dump(lr,"abalonemodel.pkl")
# Out:
# ['abalonemodel.pkl']

# %% [markdown]
# FINALLY CREATING BEST MODEL
